# %% [markdown]
# Example-1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("/content/drive/MyDrive/data/Clustering_ex.xlsx")

# %%
data
# Out:
#    Variable_1  Variable_2
# 0         1.0         1.0
# 1         1.5         2.0
# 2         3.0         4.0
# 3         5.0         7.0
# 4         3.5         5.0
# 5         4.5         5.0
# 6         3.5         4.5

# %%
fig = plt.figure(figsize=(5, 5))
x = data["Variable_1"]
y = data["Variable_2"]
n = range(1, 8)
fig, ax = plt.subplots()
ax.scatter(x, y, marker="o", c = "red", alpha = 0.5)
plt.grid()
plt.xlabel("Variable_1")
plt.ylabel("Variable_2")

for i, txt in enumerate(n):
  ax.annotate(txt, (x[i], y[i]))

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=2)

# %%
labels = kmeans.predict(data)
centroids = kmeans.cluster_centers_

# %%
centroids
# Out:
# array([[1.25, 1.5 ],
#        [3.9 , 5.1 ]])

# %%
fig = plt.figure(figsize=(5, 5))
colmap = {1: "r", 2: "b"}
colors = map(lambda x: colmap[x + 1], labels)
colors1 = list(colors)
fig, ax = plt.subplots()
ax.scatter(x, y, color = colors1, alpha=0.5, edgecolor="k")

for idx, centroid in enumerate(centroids):
  plt.scatter(*centroid, color = colmap[idx + 1])

for i, txt in enumerate(n):
  ax.annotate(txt, (x[i], y[i]))

plt.grid()
plt.xlim(0, 8)
plt.ylim(0, 8)
plt.show()

# %% [markdown]
# Example-2

# %%
data1 = pd.read_excel("/content/drive/MyDrive/data/datapoints.xlsx")
data1
# Out:
#    x   y
# 0  2  10
# 1  2   5
# 2  8   4
# 3  5   8
# 4  7   5
# 5  6   4
# 6  1   2
# 7  4   9

# %%
fig = plt.figure(figsize=(5, 5))
X = data1["x"]
Y = data1['y']

n = range(1, 9)
fig, ax = plt.subplots()
ax.scatter(X, Y, color = "red")
plt.grid()
plt.xlabel("x")
plt.ylabel("y")

for i, txt in enumerate(n):
  ax.annotate(txt, (X[i], Y[i]))

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(data1)
# Out:
# KMeans(n_clusters=3)

# %%
labels = kmeans.predict(data1)
centroids = kmeans.cluster_centers_

# %%
centroids
# Out:
# array([[3.66666667, 9.        ],
#        [7.        , 4.33333333],
#        [1.5       , 3.5       ]])

# %%
fig = plt.figure(figsize=(5, 5))
colmap = {1: "r", 2: "g", 3: "b"}

colors = map(lambda X: colmap[X + 1], labels)
colors1 = list(colors)
fig, ax = plt.subplots()
ax.scatter(X, Y, color = colors1, alpha=0.5, edgecolors="k")

for idx, centroid in enumerate(centroids):
  plt.scatter(*centroid, color = colmap[idx + 1])

for i, txt in enumerate(n):
  ax.annotate(txt, (X[i], Y[i]))

plt.grid()
plt.xlim(0, 11)
plt.ylim(0, 11)
plt.show()
